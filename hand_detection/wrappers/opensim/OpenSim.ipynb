# %%
import os 
import glob
import numpy as np
import yaml
import traceback

from utilsOpenSim import runScaleTool, getScaleTimeRange, runIKTool, generateVisualizerJson

# %%
trace_file_path = '/home/pfirouzabadi/projects/Hand_Detection/trace_files/m002/m002_trial0_RTMPoseHand5_TopDown_smoothed.trc'
model_path = 'ARM_Hand_Wrist_Model.osim'
setup_file_name = '27scales.xml'
IK_file = '27IK.xml'
root_dir = './Models'
locked_joints = ['r_x','r_y','r_z']

# %%
os.path.isfile(trace_file_path)
# Out:
# True

# %%
def scale_model(root_dir, trace_file_path, model_path, setup_file_name, locked_joints = ['r_x','r_y','r_z']):

    openSimPipelineDir = root_dir       
    
    openSimFolderName = 'Data'
    
    openSimDir = os.path.join(openSimPipelineDir, openSimFolderName)        
    outputScaledModelDir = os.path.join(openSimDir, 'Scaled_Model')


    os.makedirs(openSimDir, exist_ok=True)
    os.makedirs(outputScaledModelDir, exist_ok=True)
    # Path setup file.
    #CHANGEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
    genericSetupFile4ScalingName = (setup_file_name)
    pathGenericSetupFile4Scaling = os.path.join(
        openSimPipelineDir, genericSetupFile4ScalingName)
    # Path model file.
    pathGenericModel4Scaling = os.path.join(
        openSimPipelineDir, 
        model_path)            
    # Path TRC file.
    ##CHANGEEEEEEEEEEEEEEEEEEEEEEEEEEEE
    pathTRCFile4Scaling =  trace_file_path
    # Get time range.
    try:
        thresholdPosition = 0.003
        maxThreshold = 0.015
        increment = 0.001
        success = False
        while thresholdPosition <= maxThreshold and not success:
            try:
                timeRange4Scaling = getScaleTimeRange(
                    pathTRCFile4Scaling,
                    thresholdPosition=thresholdPosition,
                    thresholdTime=0.1, removeRoot=True)
                success = True
            except Exception as e:
                print(f"Attempt with thresholdPosition {thresholdPosition} failed: {e}")
                thresholdPosition += increment  # Increase the threshold for the next iteration

        # Run scale tool.
        print('Running Scaling')
        pathScaledModel = runScaleTool(
            pathGenericSetupFile4Scaling, 
            pathGenericModel4Scaling,
            5,
            # sessionMetadata['mass_kg'], 
            pathTRCFile4Scaling, 
            timeRange4Scaling, 
            outputScaledModelDir,
            locked_joints = ['r_x','r_y','r_z']
            # subjectHeight=sessionMetadata['height_m'],
            )
    except Exception as e:
        if len(e.args) == 2: # specific exception
            raise Exception(e.args[0], e.args[1])
        elif len(e.args) == 1: # generic exception
            exception = "Musculoskeletal model scaling failed. Verify your setup and try again. Visit https://www.opencap.ai/best-pratices to learn more about data collection and https://www.opencap.ai/troubleshooting for potential causes for a failed neutral pose."
            raise Exception(exception, traceback.format_exc())

    return pathScaledModel

# %%
pathScaledModel = scale_model(root_dir, trace_file_path, model_path, setup_file_name)
# Out:
# Static phase of 0.58s detected in staticPose between [4.26, 4.85].
# Running Scaling
# r_x  -> Coordinate Locked
# r_y  -> Coordinate Locked
# r_z  -> Coordinate Locked
# thorax
# clavicle
# clavphant
# scapula
# scapphant
# humphant
# humphant1
# humerus
# ulna
# radius
# proximal_row
# capitate
# trapezium
# trapezoid
# hamate
# firstmc1
# firstmc
# proximal_thumb
# distal_thumb
# secondmc
# thirdmc
# fourthmc
# fifthmc
# 2proxph
# 2midph
# 2distph
# 3proxph
# 3midph
# 3distph
# 4proxph
# 4midph
# 4distph
# 5proxph
# 5midph
# 5distph

# %%
def IK_model( root_dir, trace_file_path, scaled_model_path, IK_file):
    trialName = trace_file_path.split('/')[-1]
    openSimPipelineDir = root_dir
    openSimFolderName = 'Data'
    
    openSimDir = os.path.join(openSimPipelineDir, openSimFolderName)   
    pathScaledModel = scaled_model_path
    pathOutputIK = pathScaledModel[:-5]+'.mot'     
    
    # Inverse kinematics.
    outputIKDir = os.path.join(openSimDir, 'Kinematics')
    os.makedirs(outputIKDir, exist_ok=True)
    # Check if there is a scaled model.
    # pathScaledModel = os.path.join(outputScaledModelDir, 
    #                                 sessionMetadata['openSimModel'] + 
    #                                 "_scaled.osim")
    if os.path.exists(pathScaledModel):
        # Path setup file.
        genericSetupFile4IKName = IK_file
        pathGenericSetupFile4IK = os.path.join(
            openSimPipelineDir, genericSetupFile4IKName)
        # Path TRC file.
        #CHANGE
        pathTRCFile4IK = trace_file_path
        # Run IK tool. 
        print('Running Inverse Kinematics')
        try:
            pathOutputIK = runIKTool(
                pathGenericSetupFile4IK, pathScaledModel, 
                pathTRCFile4IK, outputIKDir)
        except Exception as e:
            if len(e.args) == 2: # specific exception
                raise Exception(e.args[0], e.args[1])
            elif len(e.args) == 1: # generic exception
                exception = "Inverse kinematics failed. Verify your setup and try again. Visit https://www.opencap.ai/best-pratices to learn more about data collection and https://www.opencap.ai/troubleshooting for potential causes for a failed trial."
                raise Exception(exception, traceback.format_exc())
    else:
        raise ValueError("No scaled model available.")

    # Write body transforms to json for visualization.
    outputJsonVisDir = os.path.join(outputIKDir,'VisualizerJsons',
                                    trialName)
    os.makedirs(outputJsonVisDir,exist_ok=True)
    outputJsonVisPath = os.path.join(outputJsonVisDir,
                                        trialName + '.json')
    generateVisualizerJson(pathScaledModel, pathOutputIK,
                            outputJsonVisPath, 
                            vertical_offset=0)  
    return pathOutputIK

# %%
IK_model( root_dir, trace_file_path, pathScaledModel, IK_file)
# Out:
# Running Inverse Kinematics
# [info] Preparing to run InverseKinematicsTool.
# [info] Loaded model ARM_Hand_Wrist_Model_scaled from file ./Models/Data/Scaled_Model/ARM_Hand_Wrist_Model_scaled.osim
# [warning] Couldn't find file 'thorax.vtp'.
# [warning] Couldn't find file 'clavicle.vtp'.
# [warning] Couldn't find file 'scapula.vtp'.
# [warning] Couldn't find file 'humerus.vtp'.
# [warning] Couldn't find file 'ulna.vtp'.
# [warning] Couldn't find file 'radius.vtp'.
# [warning] Couldn't find file 'lunate.vtp'.
# [warning] Couldn't find file 'sdfastSCAPHOIDw.vtp'.
# [warning] Couldn't find file 'sdfastPISIFORMw.vtp'.
# [warning] Couldn't find file 'sdfastTRIQUETRALw.vtp'.
# [warning] Couldn't find file 'capitate.vtp'.
# [warning] Couldn't find file 'trapezium.vtp'.
# [warning] Couldn't find file 'trapezoid.vtp'.
# [warning] Couldn't find file 'hamate.vtp'.
# [warning] Couldn't find file '1mc.vtp'.
# [warning] Couldn't find file 'thumbprox.vtp'.
# [warning] Couldn't find file 'thumbdist.vtp'.
# [warning] Couldn't find file '2mc.vtp'.
# [warning] Couldn't find file '3mc.vtp'.
# [warning] Couldn't find file '4mc_new.vtp'.
# [warning] Couldn't find file '5mc_new.vtp'.
# [warning] Couldn't find file '2proxph.vtp'.
# [warning] Couldn't find file '2midph.vtp'.
# [warning] Couldn't find file '2distph.vtp'.
# [warning] Couldn't find file '3proxph.vtp'.
# [warning] Couldn't find file '3midph.vtp'.
# [warning] Couldn't find file '3distph.vtp'.
# [warning] Couldn't find file '4proxph_new.vtp'.
# [warning] Couldn't find file '4midph_new.vtp'.
# [warning] Couldn't find file '4distph_new.vtp'.
# [warning] Couldn't find file '5proxph_new.vtp'.
# [warning] Couldn't find file '5midph_new.vtp'.
# [warning] Couldn't find file '5distph_new.vtp'.
#
#                MODEL: ARM_Hand_Wrist_Model_scaled
#          coordinates: 48
#               forces: 73
#            actuators: 43
#              muscles: 43
#             analyses: 0
#               probes: 0
#               bodies: 35
#               joints: 35
#          constraints: 14
#              markers: 27
#          controllers: 0
#   contact geometries: 0
# misc modelcomponents: 0
# [info] Running tool m002_trial0_RTMPoseHand5_TopDown_smoothed.
# [info] Frame 0 (t = 0.0):	 total squared error = 0.00276780, marker error: RMS = 0.0101248, max = 0.0239431 (R.Wrist.Medial.pinky)
# [info] Frame 1 (t = 0.0343879):	 total squared error = 0.00269126, marker error: RMS = 0.00998379, max = 0.0235282 (R.Wrist.Medial.pinky)
# [info] Frame 2 (t = 0.0687758):	 total squared error = 0.00270672, marker error: RMS = 0.0100124, max = 0.0232991 (R.Wrist.Medial.pinky)
# [info] Frame 3 (t = 0.103164):	 total squared error = 0.00269648, marker error: RMS = 0.00999347, max = 0.0236349 (R.Wrist.Medial.pinky)
# [info] Frame 4 (t = 0.137552):	 total squared error = 0.00270198, marker error: RMS = 0.0100037, max = 0.0239723 (R.Wrist.Medial.pinky)
# [info] Frame 5 (t = 0.171939):	 total squared error = 0.00270325, marker error: RMS = 0.0100060, max = 0.0237925 (R.Wrist.Medial.pinky)
# [info] Frame 6 (t = 0.206327):	 total squared error = 0.00269267, marker error: RMS = 0.00998641, max = 0.025188 (R.Wrist.Medial.pinky)
# [info] Frame 7 (t = 0.240715):	 total squared error = 0.00289767, marker error: RMS = 0.0103596, max = 0.0256863 (R.Wrist.Medial.pinky)
# [info] Frame 8 (t = 0.275103):	 total squared error = 0.00369854, marker error: RMS = 0.0117040, max = 0.0220830 (R.Wrist.Medial.pinky)
# [info] Frame 9 (t = 0.309491):	 total squared error = 0.00184461, marker error: RMS = 0.00826552, max = 0.0209965 (R.Wrist.Medial.pinky)
# [info] Frame 10 (t = 0.343879):	 total squared error = 0.00164516, marker error: RMS = 0.00780589, max = 0.0201723 (R.Wrist.Medial.pinky)
# [info] Frame 11 (t = 0.378267):	 total squared error = 0.00154709, marker error: RMS = 0.00756964, max = 0.0199702 (R.Wrist.Medial.pinky)
# [info] Frame 12 (t = 0.412655):	 total squared error = 0.00145127, marker error: RMS = 0.00733150, max = 0.0198846 (R.Wrist.Medial.pinky)
# [info] Frame 13 (t = 0.447043):	 total squared error = 0.00145899, marker error: RMS = 0.00735097, max = 0.0202900 (R.Wrist.Medial.pinky)
# [info] Frame 14 (t = 0.481431):	 total squared error = 0.00155141, marker error: RMS = 0.00758020, max = 0.021169 (R.Wrist.Medial.pinky)
# [info] Frame 15 (t = 0.515818):	 total squared error = 0.00161341, marker error: RMS = 0.00773019, max = 0.0222816 (R.Wrist.Medial.pinky)
# [info] Frame 16 (t = 0.550206):	 total squared error = 0.00171913, marker error: RMS = 0.00797943, max = 0.0232171 (R.Wrist.Medial.pinky)
# [info] Frame 17 (t = 0.584594):	 total squared error = 0.00175923, marker error: RMS = 0.00807196, max = 0.0238544 (R.Wrist.Medial.pinky)
# [info] Frame 18 (t = 0.618982):	 total squared error = 0.00176459, marker error: RMS = 0.00808426, max = 0.0239401 (R.Wrist.Medial.pinky)
# [info] Frame 19 (t = 0.65337):	 total squared error = 0.00179964, marker error: RMS = 0.00816415, max = 0.0245761 (R.Wrist.Medial.pinky)
# [info] Frame 20 (t = 0.687758):	 total squared error = 0.00193556, marker error: RMS = 0.00846684, max = 0.0246999 (R.Wrist.Medial.pinky)
# [info] Frame 21 (t = 0.722146):	 total squared error = 0.00177678, marker error: RMS = 0.00811214, max = 0.0240480 (R.Wrist.Medial.pinky)
# [info] Frame 22 (t = 0.756534):	 total squared error = 0.00182959, marker error: RMS = 0.00823181, max = 0.0245718 (R.Wrist.Medial.pinky)
# [info] Frame 23 (t = 0.790922):	 total squared error = 0.00180304, marker error: RMS = 0.00817187, max = 0.0237699 (R.Wrist.Medial.pinky)
# [info] Frame 24 (t = 0.825309):	 total squared error = 0.00193478, marker error: RMS = 0.00846514, max = 0.0243991 (R.Wrist.Medial.pinky)
# [info] Frame 25 (t = 0.859697):	 total squared error = 0.00215067, marker error: RMS = 0.00892493, max = 0.0263125 (R.Wrist.Medial.pinky)
# [info] Frame 26 (t = 0.894085):	 total squared error = 0.00227958, marker error: RMS = 0.00918852, max = 0.0267295 (R.Wrist.Medial.pinky)
# [info] Frame 27 (t = 0.928473):	 total squared error = 0.00227105, marker error: RMS = 0.00917132, max = 0.026882 (R.Wrist.Medial.pinky)
# [info] Frame 28 (t = 0.962861):	 total squared error = 0.00227423, marker error: RMS = 0.00917773, max = 0.0266948 (R.Wrist.Medial.pinky)
# [info] Frame 29 (t = 0.997249):	 total squared error = 0.00245998, marker error: RMS = 0.00954517, max = 0.0276062 (R.Wrist.Medial.pinky)
# [info] Frame 30 (t = 1.03164):	 total squared error = 0.00230244, marker error: RMS = 0.00923448, max = 0.0267622 (R.Wrist.Medial.pinky)
# [info] Frame 31 (t = 1.06602):	 total squared error = 0.00236183, marker error: RMS = 0.00935282, max = 0.0270602 (R.Wrist.Medial.pinky)
# [info] Frame 32 (t = 1.10041):	 total squared error = 0.00237852, marker error: RMS = 0.00938580, max = 0.0268493 (R.Wrist.Medial.pinky)
# [info] Frame 33 (t = 1.1348):	 total squared error = 0.00232390, marker error: RMS = 0.00927742, max = 0.0265233 (R.Wrist.Medial.pinky)
# [info] Frame 34 (t = 1.16919):	 total squared error = 0.00236551, marker error: RMS = 0.00936010, max = 0.026584 (R.Wrist.Medial.pinky)
# [info] Frame 35 (t = 1.20358):	 total squared error = 0.00238165, marker error: RMS = 0.00939198, max = 0.0264678 (R.Wrist.Medial.pinky)
# [info] Frame 36 (t = 1.23796):	 total squared error = 0.00255732, marker error: RMS = 0.00973218, max = 0.0263093 (R.Wrist.Medial.pinky)
# [info] Frame 37 (t = 1.27235):	 total squared error = 0.00257175, marker error: RMS = 0.00975961, max = 0.0262348 (R.Wrist.Medial.pinky)
# [info] Frame 38 (t = 1.30674):	 total squared error = 0.00248296, marker error: RMS = 0.00958966, max = 0.0252794 (R.Wrist.Medial.pinky)
# [info] Frame 39 (t = 1.34113):	 total squared error = 0.00250475, marker error: RMS = 0.00963163, max = 0.0263103 (R.Wrist.Medial.pinky)
# [info] Frame 40 (t = 1.37552):	 total squared error = 0.00319314, marker error: RMS = 0.0108749, max = 0.0255781 (R.Wrist.Medial.pinky)
# [info] Frame 41 (t = 1.40990):	 total squared error = 0.00312974, marker error: RMS = 0.0107664, max = 0.0266288 (R.Wrist.Medial.pinky)
# [info] Frame 42 (t = 1.44429):	 total squared error = 0.00268877, marker error: RMS = 0.00997918, max = 0.0267944 (R.Wrist.Medial.pinky)
# [info] Frame 43 (t = 1.47868):	 total squared error = 0.00247277, marker error: RMS = 0.00956996, max = 0.0248553 (R.Wrist.Medial.pinky)
# [info] Frame 44 (t = 1.51307):	 total squared error = 0.00254127, marker error: RMS = 0.00970160, max = 0.0245059 (R.Wrist.Medial.pinky)
# [info] Frame 45 (t = 1.54746):	 total squared error = 0.00249986, marker error: RMS = 0.00962223, max = 0.0247535 (R.Wrist.Medial.pinky)
# [info] Frame 46 (t = 1.58184):	 total squared error = 0.00275026, marker error: RMS = 0.0100927, max = 0.0256636 (R.Wrist.Medial.pinky)
# [info] Frame 47 (t = 1.61623):	 total squared error = 0.00260246, marker error: RMS = 0.00981771, max = 0.0253576 (R.Wrist.Medial.pinky)
# [info] Frame 48 (t = 1.65062):	 total squared error = 0.00266494, marker error: RMS = 0.00993486, max = 0.0258834 (R.Wrist.Medial.pinky)
# [info] Frame 49 (t = 1.68501):	 total squared error = 0.00263798, marker error: RMS = 0.00988448, max = 0.0260292 (R.Wrist.Medial.pinky)
# [info] Frame 50 (t = 1.71939):	 total squared error = 0.00263845, marker error: RMS = 0.00988536, max = 0.0257655 (R.Wrist.Medial.pinky)
# [info] Frame 51 (t = 1.75378):	 total squared error = 0.00258527, marker error: RMS = 0.00978522, max = 0.0257231 (R.Wrist.Medial.pinky)
# [info] Frame 52 (t = 1.78817):	 total squared error = 0.00256407, marker error: RMS = 0.00974502, max = 0.0256508 (R.Wrist.Medial.pinky)
# [info] Frame 53 (t = 1.82256):	 total squared error = 0.00255105, marker error: RMS = 0.00972025, max = 0.0255104 (R.Wrist.Medial.pinky)
# [info] Frame 54 (t = 1.85695):	 total squared error = 0.00252132, marker error: RMS = 0.00966344, max = 0.0253405 (R.Wrist.Medial.pinky)
# [info] Frame 55 (t = 1.89133):	 total squared error = 0.00251919, marker error: RMS = 0.00965937, max = 0.0255443 (R.Wrist.Medial.pinky)
# [info] Frame 56 (t = 1.92572):	 total squared error = 0.00252620, marker error: RMS = 0.00967279, max = 0.0252323 (R.Wrist.Medial.pinky)
# [info] Frame 57 (t = 1.96011):	 total squared error = 0.00251470, marker error: RMS = 0.00965076, max = 0.0254061 (R.Wrist.Medial.pinky)
# [info] Frame 58 (t = 1.9945):	 total squared error = 0.00249565, marker error: RMS = 0.00961412, max = 0.0252221 (R.Wrist.Medial.pinky)
# [info] Frame 59 (t = 2.02889):	 total squared error = 0.00255936, marker error: RMS = 0.00973608, max = 0.0255888 (R.Wrist.Medial.pinky)
# [info] Frame 60 (t = 2.06327):	 total squared error = 0.00254063, marker error: RMS = 0.00970038, max = 0.0254282 (R.Wrist.Medial.pinky)
# [info] Frame 61 (t = 2.09766):	 total squared error = 0.00252955, marker error: RMS = 0.00967921, max = 0.0251459 (R.Wrist.Medial.pinky)
# [info] Frame 62 (t = 2.13205):	 total squared error = 0.00268303, marker error: RMS = 0.00996853, max = 0.0249054 (R.Wrist.Medial.pinky)
# [info] Frame 63 (t = 2.16644):	 total squared error = 0.00247422, marker error: RMS = 0.00957275, max = 0.0252984 (R.Wrist.Medial.pinky)
# [info] Frame 64 (t = 2.20083):	 total squared error = 0.00264939, marker error: RMS = 0.00990583, max = 0.0251188 (R.Wrist.Medial.pinky)
# [info] Frame 65 (t = 2.23521):	 total squared error = 0.00253572, marker error: RMS = 0.00969101, max = 0.0255636 (R.Wrist.Medial.pinky)
# [info] Frame 66 (t = 2.2696):	 total squared error = 0.00253398, marker error: RMS = 0.00968768, max = 0.0255499 (R.Wrist.Medial.pinky)
# [info] Frame 67 (t = 2.30399):	 total squared error = 0.00254123, marker error: RMS = 0.00970153, max = 0.025713 (R.Wrist.Medial.pinky)
# [info] Frame 68 (t = 2.33838):	 total squared error = 0.00255845, marker error: RMS = 0.00973434, max = 0.0260461 (R.Wrist.Medial.pinky)
# [info] Frame 69 (t = 2.37276):	 total squared error = 0.00257197, marker error: RMS = 0.00976003, max = 0.0261882 (R.Wrist.Medial.pinky)
# [info] Frame 70 (t = 2.40715):	 total squared error = 0.00252723, marker error: RMS = 0.00967477, max = 0.0264639 (R.Wrist.Medial.pinky)
# [info] Frame 71 (t = 2.44154):	 total squared error = 0.00251522, marker error: RMS = 0.00965175, max = 0.0263001 (R.Wrist.Medial.pinky)
# [info] Frame 72 (t = 2.47593):	 total squared error = 0.00251379, marker error: RMS = 0.00964901, max = 0.0260807 (R.Wrist.Medial.pinky)
# [info] Frame 73 (t = 2.51032):	 total squared error = 0.00252676, marker error: RMS = 0.00967386, max = 0.0261422 (R.Wrist.Medial.pinky)
# [info] Frame 74 (t = 2.5447):	 total squared error = 0.00267001, marker error: RMS = 0.00994431, max = 0.0257685 (R.Wrist.Medial.pinky)
# [info] Frame 75 (t = 2.57909):	 total squared error = 0.00254676, marker error: RMS = 0.00971208, max = 0.0263854 (R.Wrist.Medial.pinky)
# [info] Frame 76 (t = 2.61348):	 total squared error = 0.00252123, marker error: RMS = 0.00966328, max = 0.0262173 (R.Wrist.Medial.pinky)
# [info] Frame 77 (t = 2.64787):	 total squared error = 0.00252214, marker error: RMS = 0.00966501, max = 0.0260719 (R.Wrist.Medial.pinky)
# [info] Frame 78 (t = 2.68226):	 total squared error = 0.00269443, marker error: RMS = 0.00998968, max = 0.0260663 (R.Wrist.Medial.pinky)
# [info] Frame 79 (t = 2.71664):	 total squared error = 0.00267450, marker error: RMS = 0.00995267, max = 0.0257929 (R.Wrist.Medial.pinky)
# [info] Frame 80 (t = 2.75103):	 total squared error = 0.00257221, marker error: RMS = 0.00976049, max = 0.0263884 (R.Wrist.Medial.pinky)
# [info] Frame 81 (t = 2.78542):	 total squared error = 0.00271805, marker error: RMS = 0.0100334, max = 0.0261212 (R.Wrist.Medial.pinky)
# [info] Frame 82 (t = 2.81981):	 total squared error = 0.00257748, marker error: RMS = 0.00977049, max = 0.0264078 (R.Wrist.Medial.pinky)
# [info] Frame 83 (t = 2.8542):	 total squared error = 0.00253380, marker error: RMS = 0.00968733, max = 0.0261879 (R.Wrist.Medial.pinky)
# [info] Frame 84 (t = 2.88858):	 total squared error = 0.00257402, marker error: RMS = 0.00976392, max = 0.0263454 (R.Wrist.Medial.pinky)
# [info] Frame 85 (t = 2.92297):	 total squared error = 0.00256150, marker error: RMS = 0.00974015, max = 0.0260872 (R.Wrist.Medial.pinky)
# [info] Frame 86 (t = 2.95736):	 total squared error = 0.00261357, marker error: RMS = 0.00983864, max = 0.0261037 (R.Wrist.Medial.pinky)
# [info] Frame 87 (t = 2.99175):	 total squared error = 0.00264431, marker error: RMS = 0.00989633, max = 0.0264247 (R.Wrist.Medial.pinky)
# [info] Frame 88 (t = 3.02613):	 total squared error = 0.00255329, marker error: RMS = 0.00972452, max = 0.0259833 (R.Wrist.Medial.pinky)
# [info] Frame 89 (t = 3.06052):	 total squared error = 0.00293492, marker error: RMS = 0.0104260, max = 0.0259842 (R.Wrist.Medial.pinky)
# [info] Frame 90 (t = 3.09491):	 total squared error = 0.00309730, marker error: RMS = 0.0107105, max = 0.0244412 (R.Wrist.Medial.pinky)
# [info] Frame 91 (t = 3.1293):	 total squared error = 0.00226921, marker error: RMS = 0.00916759, max = 0.0245581 (R.Wrist.Medial.pinky)
# [info] Frame 92 (t = 3.16369):	 total squared error = 0.00202709, marker error: RMS = 0.00866473, max = 0.0250246 (R.Wrist.Medial.pinky)
# [info] Frame 93 (t = 3.19807):	 total squared error = 0.00197874, marker error: RMS = 0.00856076, max = 0.0260092 (R.Wrist.Medial.pinky)
# [info] Frame 94 (t = 3.23246):	 total squared error = 0.00202989, marker error: RMS = 0.00867070, max = 0.0272769 (R.Wrist.Medial.pinky)
# [info] Frame 95 (t = 3.26685):	 total squared error = 0.00196895, marker error: RMS = 0.00853955, max = 0.0269227 (R.Wrist.Medial.pinky)
# [info] Frame 96 (t = 3.30124):	 total squared error = 0.00194812, marker error: RMS = 0.00849427, max = 0.0264191 (R.Wrist.Medial.pinky)
# [info] Frame 97 (t = 3.33563):	 total squared error = 0.00205357, marker error: RMS = 0.00872114, max = 0.0271633 (R.Wrist.Medial.pinky)
# [info] Frame 98 (t = 3.37001):	 total squared error = 0.00205574, marker error: RMS = 0.00872574, max = 0.0271467 (R.Wrist.Medial.pinky)
# [info] Frame 99 (t = 3.40440):	 total squared error = 0.00209344, marker error: RMS = 0.00880539, max = 0.0272778 (R.Wrist.Medial.pinky)
# [info] Frame 100 (t = 3.43879):	 total squared error = 0.00215430, marker error: RMS = 0.00893247, max = 0.0278554 (R.Wrist.Medial.pinky)
# [info] Frame 101 (t = 3.47318):	 total squared error = 0.00214516, marker error: RMS = 0.00891350, max = 0.0276322 (R.Wrist.Medial.pinky)
# [info] Frame 102 (t = 3.50757):	 total squared error = 0.00212422, marker error: RMS = 0.00886989, max = 0.027414 (R.Wrist.Medial.pinky)
# [info] Frame 103 (t = 3.54195):	 total squared error = 0.00207404, marker error: RMS = 0.00876450, max = 0.0267079 (R.Wrist.Medial.pinky)
# [info] Frame 104 (t = 3.57634):	 total squared error = 0.00213575, marker error: RMS = 0.00889392, max = 0.0261757 (R.Wrist.Medial.pinky)
# [info] Frame 105 (t = 3.61073):	 total squared error = 0.00204130, marker error: RMS = 0.00869503, max = 0.0243644 (R.Wrist.Medial.pinky)
# [info] Frame 106 (t = 3.64512):	 total squared error = 0.00190952, marker error: RMS = 0.00840970, max = 0.0231185 (R.Wrist.Medial.pinky)
# [info] Frame 107 (t = 3.6795):	 total squared error = 0.00129927, marker error: RMS = 0.00693693, max = 0.0170616 (R.Wrist.Medial.pinky)
# [info] Frame 108 (t = 3.71389):	 total squared error = 0.000837507, marker error: RMS = 0.00556945, max = 0.0130565 (R.Wrist.Medial.pinky)
# [info] Frame 109 (t = 3.74828):	 total squared error = 0.000520850, marker error: RMS = 0.00439212, max = 0.0103130 (MCP2)
# [info] Frame 110 (t = 3.78267):	 total squared error = 0.000190406, marker error: RMS = 0.00265557, max = 0.00556713 (MCP5)
# [info] Frame 111 (t = 3.81706):	 total squared error = 9.02457e-05, marker error: RMS = 0.00182823, max = 0.00367162 (TIP5)
# [info] Frame 112 (t = 3.85144):	 total squared error = 3.50300e-05, marker error: RMS = 0.00113904, max = 0.00233678 (MCP2)
# [info] Frame 113 (t = 3.88583):	 total squared error = 2.24814e-05, marker error: RMS = 0.000912493, max = 0.00180425 (MCP2)
# [info] Frame 114 (t = 3.92022):	 total squared error = 2.13677e-05, marker error: RMS = 0.000889605, max = 0.00187908 (CMC1)
# [info] Frame 115 (t = 3.95461):	 total squared error = 1.76445e-05, marker error: RMS = 0.000808392, max = 0.00157174 (R.Wrist.Lateral.Thumb)
# [info] Frame 116 (t = 3.989):	 total squared error = 1.6188e-05, marker error: RMS = 0.000774309, max = 0.00182468 (R.Wrist.Lateral.Thumb)
# [info] Frame 117 (t = 4.02338):	 total squared error = 1.6787e-05, marker error: RMS = 0.000788506, max = 0.00132396 (R.Wrist.Lateral.Thumb)
# [info] Frame 118 (t = 4.05777):	 total squared error = 1.25554e-05, marker error: RMS = 0.000681920, max = 0.00123952 (R.Wrist.Lateral.Thumb)
# [info] Frame 119 (t = 4.09216):	 total squared error = 1.0851e-05, marker error: RMS = 0.000633947, max = 0.00111322 (R.Wrist.Lateral.Thumb)
# [info] Frame 120 (t = 4.12655):	 total squared error = 1.08315e-05, marker error: RMS = 0.000633378, max = 0.00114912 (PIP2)
# [info] Frame 121 (t = 4.16094):	 total squared error = 1.0766e-05, marker error: RMS = 0.000631459, max = 0.00140171 (CMC1)
# [info] Frame 122 (t = 4.19532):	 total squared error = 9.77319e-06, marker error: RMS = 0.000601639, max = 0.00130416 (CMC1)
# [info] Frame 123 (t = 4.22971):	 total squared error = 9.75001e-06, marker error: RMS = 0.000600925, max = 0.00115475 (PIP2)
# [info] Frame 124 (t = 4.2641):	 total squared error = 8.12768e-06, marker error: RMS = 0.000548658, max = 0.00115344 (R.Wrist.Lateral.Thumb)
# [info] Frame 125 (t = 4.29849):	 total squared error = 6.67759e-06, marker error: RMS = 0.000497311, max = 0.00105210 (PIP2)
# [info] Frame 126 (t = 4.33287):	 total squared error = 1.02463e-05, marker error: RMS = 0.000616031, max = 0.00131900 (R.Wrist.Lateral.Thumb)
# [info] Frame 127 (t = 4.36726):	 total squared error = 6.56638e-06, marker error: RMS = 0.000493152, max = 0.00111624 (PIP2)
# [info] Frame 128 (t = 4.40165):	 total squared error = 7.33454e-06, marker error: RMS = 0.000521200, max = 0.00100007 (PIP2)
# [info] Frame 129 (t = 4.43604):	 total squared error = 8.07312e-06, marker error: RMS = 0.000546813, max = 0.000975105 (PIP2)
# [info] Frame 130 (t = 4.47043):	 total squared error = 1.10494e-05, marker error: RMS = 0.000639716, max = 0.00125950 (PIP2)
# [info] Frame 131 (t = 4.50481):	 total squared error = 1.97707e-05, marker error: RMS = 0.000855715, max = 0.00190222 (PIP2)
# [info] Frame 132 (t = 4.5392):	 total squared error = 8.65375e-06, marker error: RMS = 0.000566135, max = 0.00101295 (PIP2)
# [info] Frame 133 (t = 4.57359):	 total squared error = 8.6118e-06, marker error: RMS = 0.000564762, max = 0.00119525 (PIP2)
# [info] Frame 134 (t = 4.60798):	 total squared error = 7.28881e-06, marker error: RMS = 0.000519573, max = 0.00103043 (PIP2)
# [info] Frame 135 (t = 4.64237):	 total squared error = 9.82777e-06, marker error: RMS = 0.000603317, max = 0.00124033 (PIP2)
# [info] Frame 136 (t = 4.67675):	 total squared error = 9.84903e-06, marker error: RMS = 0.000603969, max = 0.00116646 (PIP2)
# [info] Frame 137 (t = 4.71114):	 total squared error = 9.99054e-06, marker error: RMS = 0.000608293, max = 0.00109073 (PIP2)
# [info] Frame 138 (t = 4.74553):	 total squared error = 7.72472e-06, marker error: RMS = 0.000534884, max = 0.000898445 (TIP2)
# [info] Frame 139 (t = 4.77992):	 total squared error = 6.34542e-06, marker error: RMS = 0.000484784, max = 0.000814440 (TIP2)
# [info] Frame 140 (t = 4.81431):	 total squared error = 6.40802e-06, marker error: RMS = 0.000487169, max = 0.000862493 (PIP2)
# [info] Frame 141 (t = 4.84869):	 total squared error = 7.08134e-06, marker error: RMS = 0.000512125, max = 0.000937479 (TIP5)
# [info] Frame 142 (t = 4.88308):	 total squared error = 7.76179e-06, marker error: RMS = 0.000536166, max = 0.000867333 (TIP5)
# [info] Frame 143 (t = 4.91747):	 total squared error = 8.05033e-06, marker error: RMS = 0.000546041, max = 0.000989895 (R.Wrist.Lateral.Thumb)
# [info] Frame 144 (t = 4.95186):	 total squared error = 1.12147e-05, marker error: RMS = 0.000644483, max = 0.00124899 (R.Wrist.Lateral.Thumb)
# [info] Frame 145 (t = 4.98624):	 total squared error = 1.20181e-05, marker error: RMS = 0.000667169, max = 0.00136718 (PIP2)
# [info] Frame 146 (t = 5.02063):	 total squared error = 1.11214e-05, marker error: RMS = 0.000641797, max = 0.00118177 (PIP2)
# [info] Frame 147 (t = 5.05502):	 total squared error = 1.11013e-05, marker error: RMS = 0.000641217, max = 0.00123722 (R.Wrist.Lateral.Thumb)
# [info] Frame 148 (t = 5.08941):	 total squared error = 1.3686e-05, marker error: RMS = 0.000711961, max = 0.00140809 (PIP2)
# [info] Frame 149 (t = 5.1238):	 total squared error = 1.35319e-05, marker error: RMS = 0.000707941, max = 0.00164013 (CMC1)
# [info] Frame 150 (t = 5.15818):	 total squared error = 1.47896e-05, marker error: RMS = 0.000740110, max = 0.00131960 (CMC1)
# [info] Frame 151 (t = 5.19257):	 total squared error = 3.9311e-05, marker error: RMS = 0.00120663, max = 0.00267296 (PIP2)
# [info] Frame 152 (t = 5.22696):	 total squared error = 2.13617e-05, marker error: RMS = 0.000889479, max = 0.00212083 (R.Wrist.Lateral.Thumb)
# [info] Frame 153 (t = 5.26135):	 total squared error = 2.90866e-05, marker error: RMS = 0.00103792, max = 0.00237062 (R.Wrist.Lateral.Thumb)
# [info] Frame 154 (t = 5.29574):	 total squared error = 4.64891e-05, marker error: RMS = 0.00131218, max = 0.00270382 (MCP2)
# [info] Frame 155 (t = 5.33012):	 total squared error = 9.7174e-05, marker error: RMS = 0.00189711, max = 0.00474544 (R.Wrist.Medial.pinky)
# [info] Frame 156 (t = 5.36451):	 total squared error = 0.000205822, marker error: RMS = 0.00276098, max = 0.00668172 (R.Wrist.Medial.pinky)
# [info] Frame 157 (t = 5.3989):	 total squared error = 0.000380514, marker error: RMS = 0.00375408, max = 0.00822154 (R.Wrist.Medial.pinky)
# [info] Frame 158 (t = 5.43329):	 total squared error = 0.000666772, marker error: RMS = 0.00496943, max = 0.0111966 (R.Wrist.Medial.pinky)
# [info] Frame 159 (t = 5.46768):	 total squared error = 0.000876555, marker error: RMS = 0.00569781, max = 0.0128789 (R.Wrist.Medial.pinky)
# [info] Frame 160 (t = 5.50206):	 total squared error = 0.00125085, marker error: RMS = 0.00680644, max = 0.0166189 (R.Wrist.Medial.pinky)
# [info] Frame 161 (t = 5.53645):	 total squared error = 0.00172154, marker error: RMS = 0.00798504, max = 0.0203958 (R.Wrist.Medial.pinky)
# [info] Frame 162 (t = 5.57084):	 total squared error = 0.00219584, marker error: RMS = 0.00901817, max = 0.0247958 (R.Wrist.Medial.pinky)
# [info] Frame 163 (t = 5.60523):	 total squared error = 0.00265674, marker error: RMS = 0.00991957, max = 0.0290415 (R.Wrist.Medial.pinky)
# [info] Frame 164 (t = 5.63961):	 total squared error = 0.00329000, marker error: RMS = 0.0110387, max = 0.0340391 (R.Wrist.Medial.pinky)
# [info] Frame 165 (t = 5.674):	 total squared error = 0.00381329, marker error: RMS = 0.0118842, max = 0.0371882 (R.Wrist.Medial.pinky)
# [info] Frame 166 (t = 5.70839):	 total squared error = 0.00461107, marker error: RMS = 0.0130683, max = 0.0416989 (R.Wrist.Medial.pinky)
# [info] Frame 167 (t = 5.74278):	 total squared error = 0.00545650, marker error: RMS = 0.0142159, max = 0.0459354 (R.Wrist.Medial.pinky)
# [info] Frame 168 (t = 5.77717):	 total squared error = 0.00662645, marker error: RMS = 0.015666, max = 0.0517377 (R.Wrist.Medial.pinky)
# [info] Frame 169 (t = 5.81155):	 total squared error = 0.00710298, marker error: RMS = 0.0162195, max = 0.0550748 (R.Wrist.Medial.pinky)
# [info] Frame 170 (t = 5.84594):	 total squared error = 0.00742184, marker error: RMS = 0.0165796, max = 0.0567159 (R.Wrist.Medial.pinky)
# [info] Frame 171 (t = 5.88033):	 total squared error = 0.00750091, marker error: RMS = 0.0166677, max = 0.057182 (R.Wrist.Medial.pinky)
# [info] Frame 172 (t = 5.91472):	 total squared error = 0.00761261, marker error: RMS = 0.0167913, max = 0.0575044 (R.Wrist.Medial.pinky)
# [info] Frame 173 (t = 5.94911):	 total squared error = 0.00770961, marker error: RMS = 0.016898, max = 0.0582964 (R.Wrist.Medial.pinky)
# [info] Frame 174 (t = 5.98349):	 total squared error = 0.00769138, marker error: RMS = 0.016878, max = 0.057993 (R.Wrist.Medial.pinky)
# [info] Frame 175 (t = 6.01788):	 total squared error = 0.00764963, marker error: RMS = 0.0168321, max = 0.0573159 (R.Wrist.Medial.pinky)
# [info] Frame 176 (t = 6.05227):	 total squared error = 0.00759181, marker error: RMS = 0.0167684, max = 0.0572831 (R.Wrist.Medial.pinky)
# [info] Frame 177 (t = 6.08666):	 total squared error = 0.00761099, marker error: RMS = 0.0167895, max = 0.0573187 (R.Wrist.Medial.pinky)
# [info] Frame 178 (t = 6.12105):	 total squared error = 0.00756123, marker error: RMS = 0.0167346, max = 0.0574233 (R.Wrist.Medial.pinky)
# [info] Frame 179 (t = 6.15543):	 total squared error = 0.00744872, marker error: RMS = 0.0166096, max = 0.0569966 (R.Wrist.Medial.pinky)
# [info] Frame 180 (t = 6.18982):	 total squared error = 0.00734704, marker error: RMS = 0.0164958, max = 0.0559453 (R.Wrist.Medial.pinky)
# [info] Frame 181 (t = 6.22421):	 total squared error = 0.00726015, marker error: RMS = 0.016398, max = 0.0557057 (R.Wrist.Medial.pinky)
# [info] Frame 182 (t = 6.2586):	 total squared error = 0.00720347, marker error: RMS = 0.0163339, max = 0.0555744 (R.Wrist.Medial.pinky)
# [info] Frame 183 (t = 6.29298):	 total squared error = 0.00730272, marker error: RMS = 0.016446, max = 0.0557638 (R.Wrist.Medial.pinky)
# [info] Frame 184 (t = 6.32737):	 total squared error = 0.00711102, marker error: RMS = 0.0162287, max = 0.0550707 (R.Wrist.Medial.pinky)
# [info] Frame 185 (t = 6.36176):	 total squared error = 0.00720183, marker error: RMS = 0.016332, max = 0.0555288 (R.Wrist.Medial.pinky)
# [info] Frame 186 (t = 6.39615):	 total squared error = 0.00720916, marker error: RMS = 0.0163403, max = 0.0558032 (R.Wrist.Medial.pinky)
# [info] Frame 187 (t = 6.43054):	 total squared error = 0.00721631, marker error: RMS = 0.0163484, max = 0.05574 (R.Wrist.Medial.pinky)
# [info] Frame 188 (t = 6.46492):	 total squared error = 0.00717986, marker error: RMS = 0.0163071, max = 0.055449 (R.Wrist.Medial.pinky)
# [info] Frame 189 (t = 6.49931):	 total squared error = 0.00722962, marker error: RMS = 0.0163635, max = 0.0557855 (R.Wrist.Medial.pinky)
# [info] Frame 190 (t = 6.5337):	 total squared error = 0.00717095, marker error: RMS = 0.016297, max = 0.0555831 (R.Wrist.Medial.pinky)
# [info] Frame 191 (t = 6.56809):	 total squared error = 0.00719759, marker error: RMS = 0.0163272, max = 0.0560777 (R.Wrist.Medial.pinky)
# [info] Frame 192 (t = 6.60248):	 total squared error = 0.00729799, marker error: RMS = 0.0164407, max = 0.0560325 (R.Wrist.Medial.pinky)
# [info] Frame 193 (t = 6.63686):	 total squared error = 0.00719812, marker error: RMS = 0.0163278, max = 0.0555999 (R.Wrist.Medial.pinky)
# [info] Frame 194 (t = 6.67125):	 total squared error = 0.00717440, marker error: RMS = 0.0163009, max = 0.0557507 (R.Wrist.Medial.pinky)
# [info] Frame 195 (t = 6.70564):	 total squared error = 0.00711623, marker error: RMS = 0.0162347, max = 0.0556358 (R.Wrist.Medial.pinky)
# [info] Frame 196 (t = 6.74003):	 total squared error = 0.00714000, marker error: RMS = 0.0162617, max = 0.0554299 (R.Wrist.Medial.pinky)
# [info] Frame 197 (t = 6.77442):	 total squared error = 0.00714901, marker error: RMS = 0.016272, max = 0.0555848 (R.Wrist.Medial.pinky)
# [info] Frame 198 (t = 6.80880):	 total squared error = 0.00711576, marker error: RMS = 0.0162341, max = 0.0553019 (R.Wrist.Medial.pinky)
# [info] Frame 199 (t = 6.84319):	 total squared error = 0.00704278, marker error: RMS = 0.0161507, max = 0.0548636 (R.Wrist.Medial.pinky)
# [info] Frame 200 (t = 6.87758):	 total squared error = 0.00699366, marker error: RMS = 0.0160942, max = 0.0544026 (R.Wrist.Medial.pinky)
# [info] Frame 201 (t = 6.91197):	 total squared error = 0.00698034, marker error: RMS = 0.0160789, max = 0.0545061 (R.Wrist.Medial.pinky)
# [info] Frame 202 (t = 6.94635):	 total squared error = 0.00697970, marker error: RMS = 0.0160782, max = 0.0543705 (R.Wrist.Medial.pinky)
# [info] Frame 203 (t = 6.98074):	 total squared error = 0.00698537, marker error: RMS = 0.0160847, max = 0.0544866 (R.Wrist.Medial.pinky)
# [info] Frame 204 (t = 7.01513):	 total squared error = 0.00707167, marker error: RMS = 0.0161838, max = 0.0546476 (R.Wrist.Medial.pinky)
# [info] Frame 205 (t = 7.04952):	 total squared error = 0.00697631, marker error: RMS = 0.0160743, max = 0.0549918 (R.Wrist.Medial.pinky)
# [info] Frame 206 (t = 7.08391):	 total squared error = 0.00711505, marker error: RMS = 0.0162333, max = 0.0551201 (R.Wrist.Medial.pinky)
# [info] Frame 207 (t = 7.11829):	 total squared error = 0.00803774, marker error: RMS = 0.0172538, max = 0.0558298 (R.Wrist.Lateral.Thumb)
# [info] Frame 208 (t = 7.15268):	 total squared error = 0.00770304, marker error: RMS = 0.0168908, max = 0.0555202 (R.Wrist.Lateral.Thumb)
# [info] Frame 209 (t = 7.18707):	 total squared error = 0.00747066, marker error: RMS = 0.016634, max = 0.0565206 (R.Wrist.Lateral.Thumb)
# [info] Frame 210 (t = 7.22146):	 total squared error = 0.00749216, marker error: RMS = 0.0166579, max = 0.0564175 (R.Wrist.Lateral.Thumb)
# [info] Frame 211 (t = 7.25585):	 total squared error = 0.00772209, marker error: RMS = 0.0169116, max = 0.0566821 (R.Wrist.Lateral.Thumb)
# [info] Frame 212 (t = 7.29023):	 total squared error = 0.00795775, marker error: RMS = 0.0171677, max = 0.0571133 (R.Wrist.Lateral.Thumb)
# [info] Frame 213 (t = 7.32462):	 total squared error = 0.00786627, marker error: RMS = 0.0170688, max = 0.0558444 (R.Wrist.Lateral.Thumb)
# [info] Frame 214 (t = 7.35901):	 total squared error = 0.00791659, marker error: RMS = 0.0171233, max = 0.0558623 (R.Wrist.Lateral.Thumb)
# [info] Frame 215 (t = 7.3934):	 total squared error = 0.00789351, marker error: RMS = 0.0170983, max = 0.0556173 (R.Wrist.Lateral.Thumb)
# [info] Frame 216 (t = 7.42779):	 total squared error = 0.00813142, marker error: RMS = 0.0173541, max = 0.0565424 (R.Wrist.Lateral.Thumb)
# [info] Frame 217 (t = 7.46217):	 total squared error = 0.00791900, marker error: RMS = 0.0171259, max = 0.05597 (R.Wrist.Lateral.Thumb)
# [info] Frame 218 (t = 7.49656):	 total squared error = 0.00790332, marker error: RMS = 0.0171089, max = 0.0556032 (R.Wrist.Lateral.Thumb)
# [info] Frame 219 (t = 7.53095):	 total squared error = 0.00787080, marker error: RMS = 0.0170737, max = 0.0555654 (R.Wrist.Medial.pinky)
# [info] Frame 220 (t = 7.56534):	 total squared error = 0.00810623, marker error: RMS = 0.0173272, max = 0.0555538 (R.Wrist.Lateral.Thumb)
# [info] Frame 221 (t = 7.59972):	 total squared error = 0.00791409, marker error: RMS = 0.0171206, max = 0.0570385 (R.Wrist.Medial.pinky)
# [info] Frame 222 (t = 7.63411):	 total squared error = 0.00788223, marker error: RMS = 0.0170861, max = 0.0561777 (R.Wrist.Medial.pinky)
# [info] Frame 223 (t = 7.6685):	 total squared error = 0.00783267, marker error: RMS = 0.0170323, max = 0.0560029 (R.Wrist.Medial.pinky)
# [info] Frame 224 (t = 7.70289):	 total squared error = 0.00784404, marker error: RMS = 0.0170446, max = 0.0556764 (R.Wrist.Medial.pinky)
# [info] Frame 225 (t = 7.73728):	 total squared error = 0.00797616, marker error: RMS = 0.0171876, max = 0.0550105 (R.Wrist.Lateral.Thumb)
# [info] Frame 226 (t = 7.77166):	 total squared error = 0.00784183, marker error: RMS = 0.0170422, max = 0.0555528 (R.Wrist.Medial.pinky)
# [info] Frame 227 (t = 7.80605):	 total squared error = 0.00781760, marker error: RMS = 0.0170159, max = 0.0550679 (R.Wrist.Medial.pinky)
# [info] Frame 228 (t = 7.84044):	 total squared error = 0.00783939, marker error: RMS = 0.0170396, max = 0.0552826 (R.Wrist.Medial.pinky)
# [info] Frame 229 (t = 7.87483):	 total squared error = 0.00796502, marker error: RMS = 0.0171756, max = 0.0554436 (R.Wrist.Lateral.Thumb)
# [info] Frame 230 (t = 7.90922):	 total squared error = 0.00778003, marker error: RMS = 0.016975, max = 0.0552513 (R.Wrist.Medial.pinky)
# [info] Frame 231 (t = 7.9436):	 total squared error = 0.00774840, marker error: RMS = 0.0169404, max = 0.0556594 (R.Wrist.Medial.pinky)
# [info] Frame 232 (t = 7.97799):	 total squared error = 0.00761927, marker error: RMS = 0.0167987, max = 0.0556569 (R.Wrist.Medial.pinky)
# [info] Frame 233 (t = 8.01238):	 total squared error = 0.00766964, marker error: RMS = 0.0168541, max = 0.0562506 (R.Wrist.Medial.pinky)
# [info] Frame 234 (t = 8.04677):	 total squared error = 0.00772160, marker error: RMS = 0.0169111, max = 0.0560411 (R.Wrist.Medial.pinky)
# [info] Frame 235 (t = 8.08116):	 total squared error = 0.00802647, marker error: RMS = 0.0172417, max = 0.0569459 (R.Wrist.Medial.pinky)
# [info] Frame 236 (t = 8.11554):	 total squared error = 0.00726673, marker error: RMS = 0.0164054, max = 0.0568158 (R.Wrist.Medial.pinky)
# [info] Frame 237 (t = 8.14993):	 total squared error = 0.00731905, marker error: RMS = 0.0164644, max = 0.0553124 (R.Wrist.Medial.pinky)
# [info] Frame 238 (t = 8.18432):	 total squared error = 0.00710502, marker error: RMS = 0.0162219, max = 0.0536287 (R.Wrist.Medial.pinky)
# [info] Frame 239 (t = 8.21871):	 total squared error = 0.00697563, marker error: RMS = 0.0160735, max = 0.0532995 (R.Wrist.Medial.pinky)
# [info] Frame 240 (t = 8.25309):	 total squared error = 0.00701594, marker error: RMS = 0.0161199, max = 0.0536399 (R.Wrist.Medial.pinky)
# [info] Frame 241 (t = 8.28748):	 total squared error = 0.00693678, marker error: RMS = 0.0160287, max = 0.0532509 (R.Wrist.Medial.pinky)
# [info] Frame 242 (t = 8.32187):	 total squared error = 0.00702972, marker error: RMS = 0.0161357, max = 0.0538193 (R.Wrist.Medial.pinky)
# [info] Frame 243 (t = 8.35626):	 total squared error = 0.00692727, marker error: RMS = 0.0160177, max = 0.053312 (R.Wrist.Medial.pinky)
# [info] Frame 244 (t = 8.39065):	 total squared error = 0.00691808, marker error: RMS = 0.0160070, max = 0.0531925 (R.Wrist.Medial.pinky)
# [info] Frame 245 (t = 8.42503):	 total squared error = 0.00689879, marker error: RMS = 0.0159847, max = 0.0529336 (R.Wrist.Medial.pinky)
# [info] Frame 246 (t = 8.45942):	 total squared error = 0.00688471, marker error: RMS = 0.0159684, max = 0.0529567 (R.Wrist.Medial.pinky)
# [info] Frame 247 (t = 8.49381):	 total squared error = 0.00686984, marker error: RMS = 0.0159511, max = 0.0525945 (R.Wrist.Medial.pinky)
# [info] Frame 248 (t = 8.5282):	 total squared error = 0.00683595, marker error: RMS = 0.0159117, max = 0.0525336 (R.Wrist.Medial.pinky)
# [info] Frame 249 (t = 8.56259):	 total squared error = 0.00682577, marker error: RMS = 0.0158999, max = 0.0524282 (R.Wrist.Medial.pinky)
# [info] Frame 250 (t = 8.59697):	 total squared error = 0.00699060, marker error: RMS = 0.0160907, max = 0.0530304 (R.Wrist.Medial.pinky)
# [info] Frame 251 (t = 8.63136):	 total squared error = 0.00679011, marker error: RMS = 0.0158583, max = 0.0524596 (R.Wrist.Medial.pinky)
# [info] Frame 252 (t = 8.66575):	 total squared error = 0.00697172, marker error: RMS = 0.0160690, max = 0.0532692 (R.Wrist.Medial.pinky)
# [info] Frame 253 (t = 8.70014):	 total squared error = 0.00680585, marker error: RMS = 0.0158767, max = 0.0523211 (R.Wrist.Medial.pinky)
# [info] Frame 254 (t = 8.73453):	 total squared error = 0.00683708, marker error: RMS = 0.015913, max = 0.0527219 (R.Wrist.Medial.pinky)
# [info] Frame 255 (t = 8.76891):	 total squared error = 0.00685018, marker error: RMS = 0.0159283, max = 0.0521169 (R.Wrist.Medial.pinky)
# [info] Frame 256 (t = 8.80330):	 total squared error = 0.00683387, marker error: RMS = 0.0159093, max = 0.0515987 (R.Wrist.Medial.pinky)
# [info] Frame 257 (t = 8.83769):	 total squared error = 0.00678738, marker error: RMS = 0.0158551, max = 0.0524253 (R.Wrist.Medial.pinky)
# [info] Frame 258 (t = 8.87208):	 total squared error = 0.00704623, marker error: RMS = 0.0161546, max = 0.0540818 (R.Wrist.Medial.pinky)
# [info] Frame 259 (t = 8.90646):	 total squared error = 0.00759548, marker error: RMS = 0.0167724, max = 0.0527818 (R.Wrist.Medial.pinky)
# [info] Frame 260 (t = 8.94085):	 total squared error = 0.00791265, marker error: RMS = 0.017119, max = 0.0536707 (R.Wrist.Medial.pinky)
# [info] Frame 261 (t = 8.97524):	 total squared error = 0.00803805, marker error: RMS = 0.0172541, max = 0.0538227 (R.Wrist.Medial.pinky)
# [info] Frame 262 (t = 9.00963):	 total squared error = 0.00817351, marker error: RMS = 0.0173989, max = 0.0544075 (R.Wrist.Medial.pinky)
# [info] Frame 263 (t = 9.04402):	 total squared error = 0.00823785, marker error: RMS = 0.0174673, max = 0.0552783 (R.Wrist.Lateral.Thumb)
# [info] Frame 264 (t = 9.0784):	 total squared error = 0.00825000, marker error: RMS = 0.0174801, max = 0.0562158 (R.Wrist.Lateral.Thumb)
# [info] Frame 265 (t = 9.11279):	 total squared error = 0.00824893, marker error: RMS = 0.017479, max = 0.0565589 (R.Wrist.Lateral.Thumb)
# [info] Frame 266 (t = 9.14718):	 total squared error = 0.00824868, marker error: RMS = 0.0174787, max = 0.0569183 (R.Wrist.Lateral.Thumb)
# [info] Frame 267 (t = 9.18157):	 total squared error = 0.00830339, marker error: RMS = 0.0175366, max = 0.0566279 (R.Wrist.Lateral.Thumb)
# [info] Frame 268 (t = 9.21596):	 total squared error = 0.00828270, marker error: RMS = 0.0175148, max = 0.0558847 (R.Wrist.Lateral.Thumb)
# [info] Frame 269 (t = 9.25034):	 total squared error = 0.00831801, marker error: RMS = 0.017552, max = 0.0556947 (R.Wrist.Lateral.Thumb)
# [info] Frame 270 (t = 9.28473):	 total squared error = 0.00834672, marker error: RMS = 0.0175823, max = 0.0557317 (R.Wrist.Medial.pinky)
# [info] Frame 271 (t = 9.31912):	 total squared error = 0.00837355, marker error: RMS = 0.0176106, max = 0.0557124 (R.Wrist.Medial.pinky)
# [info] Frame 272 (t = 9.35351):	 total squared error = 0.00838747, marker error: RMS = 0.0176252, max = 0.0558046 (R.Wrist.Medial.pinky)
# [info] Frame 273 (t = 9.3879):	 total squared error = 0.00842101, marker error: RMS = 0.0176604, max = 0.0558352 (R.Wrist.Medial.pinky)
# [info] Frame 274 (t = 9.42228):	 total squared error = 0.00831698, marker error: RMS = 0.017551, max = 0.0557721 (R.Wrist.Lateral.Thumb)
# [info] Frame 275 (t = 9.45667):	 total squared error = 0.00831493, marker error: RMS = 0.0175488, max = 0.0557155 (R.Wrist.Lateral.Thumb)
# [info] Frame 276 (t = 9.49106):	 total squared error = 0.00853009, marker error: RMS = 0.0177744, max = 0.0569544 (R.Wrist.Lateral.Thumb)
# [info] Frame 277 (t = 9.52545):	 total squared error = 0.00808277, marker error: RMS = 0.0173021, max = 0.0560448 (R.Wrist.Lateral.Thumb)
# [info] Frame 278 (t = 9.55983):	 total squared error = 0.00796302, marker error: RMS = 0.0171734, max = 0.0562164 (R.Wrist.Lateral.Thumb)
# [info] Frame 279 (t = 9.59422):	 total squared error = 0.00783014, marker error: RMS = 0.0170295, max = 0.0560462 (R.Wrist.Lateral.Thumb)
# [info] Frame 280 (t = 9.62861):	 total squared error = 0.00834016, marker error: RMS = 0.0175754, max = 0.0562373 (R.Wrist.Lateral.Thumb)
# [info] Frame 281 (t = 9.663):	 total squared error = 0.00763823, marker error: RMS = 0.0168196, max = 0.051148 (R.Wrist.Lateral.Thumb)
# [info] Frame 282 (t = 9.69739):	 total squared error = 0.00695726, marker error: RMS = 0.0160523, max = 0.0513261 (R.Wrist.Medial.pinky)
# [info] Frame 283 (t = 9.73177):	 total squared error = 0.00654966, marker error: RMS = 0.015575, max = 0.0514206 (R.Wrist.Medial.pinky)
# [info] Frame 284 (t = 9.76616):	 total squared error = 0.00643047, marker error: RMS = 0.0154326, max = 0.0497776 (R.Wrist.Medial.pinky)
# [info] Frame 285 (t = 9.80055):	 total squared error = 0.00678920, marker error: RMS = 0.0158572, max = 0.0498765 (R.Wrist.Medial.pinky)
# [info] Frame 286 (t = 9.83494):	 total squared error = 0.00702181, marker error: RMS = 0.0161266, max = 0.0508735 (R.Wrist.Medial.pinky)
# [info] Frame 287 (t = 9.86933):	 total squared error = 0.00711682, marker error: RMS = 0.0162353, max = 0.0509923 (R.Wrist.Medial.pinky)
# [info] Frame 288 (t = 9.90371):	 total squared error = 0.00722587, marker error: RMS = 0.0163592, max = 0.0520037 (R.Wrist.Medial.pinky)
# [info] Frame 289 (t = 9.9381):	 total squared error = 0.00732505, marker error: RMS = 0.0164711, max = 0.0531713 (R.Wrist.Medial.pinky)
# [info] Frame 290 (t = 9.97249):	 total squared error = 0.00724782, marker error: RMS = 0.0163841, max = 0.0523423 (R.Wrist.Medial.pinky)
# [info] Frame 291 (t = 10.0069):	 total squared error = 0.00726960, marker error: RMS = 0.0164087, max = 0.052629 (R.Wrist.Medial.pinky)
# [info] Frame 292 (t = 10.0413):	 total squared error = 0.00726781, marker error: RMS = 0.0164067, max = 0.0526351 (R.Wrist.Medial.pinky)
# [info] Frame 293 (t = 10.0757):	 total squared error = 0.00723851, marker error: RMS = 0.0163735, max = 0.052866 (R.Wrist.Medial.pinky)
# [info] Frame 294 (t = 10.11):	 total squared error = 0.00737498, marker error: RMS = 0.0165272, max = 0.053161 (R.Wrist.Medial.pinky)
# [info] Frame 295 (t = 10.1444):	 total squared error = 0.00714936, marker error: RMS = 0.0162724, max = 0.0522095 (R.Wrist.Medial.pinky)
# [info] Frame 296 (t = 10.1788):	 total squared error = 0.00709884, marker error: RMS = 0.0162148, max = 0.0520939 (R.Wrist.Medial.pinky)
# [info] Frame 297 (t = 10.2132):	 total squared error = 0.00703908, marker error: RMS = 0.0161464, max = 0.0518493 (R.Wrist.Medial.pinky)
# [info] Frame 298 (t = 10.2476):	 total squared error = 0.00698637, marker error: RMS = 0.0160858, max = 0.0516243 (R.Wrist.Medial.pinky)
# [info] Frame 299 (t = 10.282):	 total squared error = 0.00694092, marker error: RMS = 0.0160334, max = 0.0516482 (R.Wrist.Medial.pinky)
# [info] Frame 300 (t = 10.3164):	 total squared error = 0.00691319, marker error: RMS = 0.0160014, max = 0.0511242 (R.Wrist.Medial.pinky)
# [info] Frame 301 (t = 10.3508):	 total squared error = 0.00678019, marker error: RMS = 0.0158467, max = 0.0508976 (R.Wrist.Medial.pinky)
# [info] Frame 302 (t = 10.3851):	 total squared error = 0.00660766, marker error: RMS = 0.0156438, max = 0.0512768 (R.Wrist.Medial.pinky)
# [info] Frame 303 (t = 10.4195):	 total squared error = 0.00688156, marker error: RMS = 0.0159647, max = 0.0532367 (R.Wrist.Medial.pinky)
# [info] Frame 304 (t = 10.4539):	 total squared error = 0.00718396, marker error: RMS = 0.0163117, max = 0.0550285 (R.Wrist.Medial.pinky)
# [info] Frame 305 (t = 10.4883):	 total squared error = 0.00741048, marker error: RMS = 0.0165669, max = 0.0558587 (R.Wrist.Medial.pinky)
# [info] Frame 306 (t = 10.5227):	 total squared error = 0.00753609, marker error: RMS = 0.0167067, max = 0.0558036 (R.Wrist.Medial.pinky)
# [info] Frame 307 (t = 10.5571):	 total squared error = 0.00761692, marker error: RMS = 0.0167961, max = 0.0554205 (R.Wrist.Medial.pinky)
# [info] Frame 308 (t = 10.5915):	 total squared error = 0.00766379, marker error: RMS = 0.0168477, max = 0.0556384 (R.Wrist.Medial.pinky)
# [info] Frame 309 (t = 10.6259):	 total squared error = 0.00772005, marker error: RMS = 0.0169094, max = 0.056252 (R.Wrist.Medial.pinky)
# [info] Frame 310 (t = 10.6602):	 total squared error = 0.00767574, marker error: RMS = 0.0168608, max = 0.0560783 (R.Wrist.Medial.pinky)
# [info] Frame 311 (t = 10.6946):	 total squared error = 0.00747057, marker error: RMS = 0.0166339, max = 0.0557059 (R.Wrist.Medial.pinky)
# [info] Frame 312 (t = 10.729):	 total squared error = 0.00710512, marker error: RMS = 0.016222, max = 0.0538029 (R.Wrist.Medial.pinky)
# [info] Frame 313 (t = 10.7634):	 total squared error = 0.00701034, marker error: RMS = 0.0161134, max = 0.0532287 (R.Wrist.Medial.pinky)
# [info] Frame 314 (t = 10.7978):	 total squared error = 0.00687292, marker error: RMS = 0.0159547, max = 0.0536369 (R.Wrist.Medial.pinky)
# [info] Frame 315 (t = 10.8322):	 total squared error = 0.00693817, marker error: RMS = 0.0160303, max = 0.0536097 (R.Wrist.Medial.pinky)
# [info] Frame 316 (t = 10.8666):	 total squared error = 0.00700234, marker error: RMS = 0.0161042, max = 0.0543269 (R.Wrist.Medial.pinky)
# [info] Frame 317 (t = 10.9010):	 total squared error = 0.00718103, marker error: RMS = 0.0163084, max = 0.0559371 (R.Wrist.Medial.pinky)
# [info] Frame 318 (t = 10.9354):	 total squared error = 0.00722956, marker error: RMS = 0.0163634, max = 0.0559938 (R.Wrist.Medial.pinky)
# [info] Frame 319 (t = 10.9697):	 total squared error = 0.00730958, marker error: RMS = 0.0164537, max = 0.0565747 (R.Wrist.Medial.pinky)
# [info] Frame 320 (t = 11.0041):	 total squared error = 0.00733518, marker error: RMS = 0.0164825, max = 0.056868 (R.Wrist.Medial.pinky)
# [info] Frame 321 (t = 11.0385):	 total squared error = 0.00729927, marker error: RMS = 0.0164421, max = 0.0563529 (R.Wrist.Medial.pinky)
# [info] Frame 322 (t = 11.0729):	 total squared error = 0.00722644, marker error: RMS = 0.0163599, max = 0.0559743 (R.Wrist.Medial.pinky)
# [info] Frame 323 (t = 11.1073):	 total squared error = 0.00717552, marker error: RMS = 0.0163021, max = 0.0560024 (R.Wrist.Medial.pinky)
# [info] Frame 324 (t = 11.1417):	 total squared error = 0.00714260, marker error: RMS = 0.0162647, max = 0.0554917 (R.Wrist.Medial.pinky)
# [info] Frame 325 (t = 11.1761):	 total squared error = 0.00718760, marker error: RMS = 0.0163159, max = 0.0546028 (R.Wrist.Medial.pinky)
# [info] Frame 326 (t = 11.2105):	 total squared error = 0.00721875, marker error: RMS = 0.0163512, max = 0.0543324 (R.Wrist.Medial.pinky)
# [info] Frame 327 (t = 11.2448):	 total squared error = 0.00711545, marker error: RMS = 0.0162338, max = 0.0580315 (R.Wrist.Medial.pinky)
# [info] Frame 328 (t = 11.2792):	 total squared error = 0.00704211, marker error: RMS = 0.0161499, max = 0.0583226 (R.Wrist.Medial.pinky)
# [info] Frame 329 (t = 11.3136):	 total squared error = 0.00703189, marker error: RMS = 0.0161382, max = 0.0585594 (R.Wrist.Medial.pinky)
# [info] Frame 330 (t = 11.348):	 total squared error = 0.00695649, marker error: RMS = 0.0160514, max = 0.0578218 (R.Wrist.Medial.pinky)
# [info] Frame 331 (t = 11.3824):	 total squared error = 0.00702767, marker error: RMS = 0.0161333, max = 0.0579188 (R.Wrist.Medial.pinky)
# [info] Frame 332 (t = 11.4168):	 total squared error = 0.00715787, marker error: RMS = 0.0162821, max = 0.0579659 (R.Wrist.Medial.pinky)
# [info] Frame 333 (t = 11.4512):	 total squared error = 0.00711588, marker error: RMS = 0.0162343, max = 0.0554578 (R.Wrist.Medial.pinky)
# [info] Frame 334 (t = 11.4856):	 total squared error = 0.00713627, marker error: RMS = 0.0162575, max = 0.0555178 (R.Wrist.Medial.pinky)
# [info] Frame 335 (t = 11.5199):	 total squared error = 0.00723335, marker error: RMS = 0.0163677, max = 0.0560165 (R.Wrist.Medial.pinky)
# [info] Frame 336 (t = 11.5543):	 total squared error = 0.00727027, marker error: RMS = 0.0164094, max = 0.0564052 (R.Wrist.Medial.pinky)
# ...
# [info] Frame 814 (t = 27.9917):	 total squared error = 0.00129904, marker error: RMS = 0.00693633, max = 0.0165786 (R.Wrist.Medial.pinky)
# [info] Frame 815 (t = 28.0261):	 total squared error = 0.00180790, marker error: RMS = 0.00818287, max = 0.0197454 (R.Wrist.Medial.pinky)
# [info] Frame 816 (t = 28.0605):	 total squared error = 0.00241009, marker error: RMS = 0.00944789, max = 0.0267666 (R.Wrist.Medial.pinky)
# [info] Frame 817 (t = 28.0949):	 total squared error = 0.00324249, marker error: RMS = 0.0109587, max = 0.0325050 (R.Wrist.Medial.pinky)
# [info] Frame 818 (t = 28.1293):	 total squared error = 0.00434189, marker error: RMS = 0.0126811, max = 0.0396424 (R.Wrist.Medial.pinky)
# [info] Frame 819 (t = 28.1637):	 total squared error = 0.00468623, marker error: RMS = 0.0131744, max = 0.0425251 (R.Wrist.Medial.pinky)
# [info] Frame 820 (t = 28.1981):	 total squared error = 0.00555503, marker error: RMS = 0.0143437, max = 0.0463539 (R.Wrist.Medial.pinky)
# [info] Frame 821 (t = 28.2325):	 total squared error = 0.00634298, marker error: RMS = 0.0153273, max = 0.049663 (R.Wrist.Medial.pinky)
# [info] Frame 822 (t = 28.2669):	 total squared error = 0.00686413, marker error: RMS = 0.0159445, max = 0.0530117 (R.Wrist.Medial.pinky)
# [info] Frame 823 (t = 28.3012):	 total squared error = 0.00721414, marker error: RMS = 0.016346, max = 0.055117 (R.Wrist.Medial.pinky)
# [info] Frame 824 (t = 28.3356):	 total squared error = 0.00740709, marker error: RMS = 0.0165631, max = 0.0564333 (R.Wrist.Medial.pinky)
# [info] Frame 825 (t = 28.37):	 total squared error = 0.00747770, marker error: RMS = 0.0166419, max = 0.0571961 (R.Wrist.Medial.pinky)
# [info] Frame 826 (t = 28.4044):	 total squared error = 0.00756684, marker error: RMS = 0.0167408, max = 0.0576122 (R.Wrist.Medial.pinky)
# [info] Frame 827 (t = 28.4388):	 total squared error = 0.00757753, marker error: RMS = 0.0167526, max = 0.0578459 (R.Wrist.Medial.pinky)
# [info] Frame 828 (t = 28.4732):	 total squared error = 0.00761090, marker error: RMS = 0.0167894, max = 0.0573046 (R.Wrist.Medial.pinky)
# [info] Frame 829 (t = 28.5076):	 total squared error = 0.00757777, marker error: RMS = 0.0167529, max = 0.0572041 (R.Wrist.Medial.pinky)
# [info] Frame 830 (t = 28.542):	 total squared error = 0.00756516, marker error: RMS = 0.0167389, max = 0.0570455 (R.Wrist.Medial.pinky)
# [info] Frame 831 (t = 28.5763):	 total squared error = 0.00752485, marker error: RMS = 0.0166943, max = 0.0571365 (R.Wrist.Medial.pinky)
# [info] Frame 832 (t = 28.6107):	 total squared error = 0.00746849, marker error: RMS = 0.0166316, max = 0.0571033 (R.Wrist.Medial.pinky)
# [info] Frame 833 (t = 28.6451):	 total squared error = 0.00744025, marker error: RMS = 0.0166001, max = 0.0570193 (R.Wrist.Medial.pinky)
# [info] Frame 834 (t = 28.6795):	 total squared error = 0.00725706, marker error: RMS = 0.0163945, max = 0.0563034 (R.Wrist.Medial.pinky)
# [info] Frame 835 (t = 28.7139):	 total squared error = 0.00691955, marker error: RMS = 0.0160087, max = 0.0542317 (R.Wrist.Medial.pinky)
# [info] Frame 836 (t = 28.7483):	 total squared error = 0.00637625, marker error: RMS = 0.0153674, max = 0.0499731 (R.Wrist.Medial.pinky)
# [info] Frame 837 (t = 28.7827):	 total squared error = 0.00513591, marker error: RMS = 0.013792, max = 0.0431972 (R.Wrist.Medial.pinky)
# [info] Frame 838 (t = 28.8171):	 total squared error = 0.00466053, marker error: RMS = 0.0131382, max = 0.0395188 (R.Wrist.Medial.pinky)
# [info] Frame 839 (t = 28.8514):	 total squared error = 0.00395617, marker error: RMS = 0.0121047, max = 0.0342376 (R.Wrist.Medial.pinky)
# [info] Frame 840 (t = 28.8858):	 total squared error = 0.00279985, marker error: RMS = 0.0101832, max = 0.029861 (R.Wrist.Medial.pinky)
# [info] Frame 841 (t = 28.9202):	 total squared error = 0.00269466, marker error: RMS = 0.00999011, max = 0.0247733 (R.Wrist.Medial.pinky)
# [info] Frame 842 (t = 28.9546):	 total squared error = 0.00233024, marker error: RMS = 0.00929005, max = 0.0206293 (R.Wrist.Medial.pinky)
# [info] Frame 843 (t = 28.989):	 total squared error = 0.00230689, marker error: RMS = 0.00924340, max = 0.0170090 (R.Wrist.Medial.pinky)
# [info] Frame 844 (t = 29.0234):	 total squared error = 0.00214146, marker error: RMS = 0.00890580, max = 0.0148742 (MCP2)
# [info] Frame 845 (t = 29.0578):	 total squared error = 0.00198020, marker error: RMS = 0.00856392, max = 0.0125383 (DIP4)
# [info] Frame 846 (t = 29.0922):	 total squared error = 0.00208747, marker error: RMS = 0.00879281, max = 0.0133641 (TIP3)
# [info] Frame 847 (t = 29.1265):	 total squared error = 0.00193955, marker error: RMS = 0.00847556, max = 0.012431 (DIP4)
# [info] Frame 848 (t = 29.1609):	 total squared error = 0.00211413, marker error: RMS = 0.00884880, max = 0.0128961 (CMC1)
# [info] Frame 849 (t = 29.1953):	 total squared error = 0.00214413, marker error: RMS = 0.00891135, max = 0.0130858 (CMC1)
# [info] Frame 850 (t = 29.2297):	 total squared error = 0.00219119, marker error: RMS = 0.00900863, max = 0.0130488 (CMC1)
# [info] Frame 851 (t = 29.2641):	 total squared error = 0.00215299, marker error: RMS = 0.00892974, max = 0.0130356 (CMC1)
# [info] Frame 852 (t = 29.2985):	 total squared error = 0.00209365, marker error: RMS = 0.00880584, max = 0.0138111 (MCP4)
# [info] Frame 853 (t = 29.3329):	 total squared error = 0.00207547, marker error: RMS = 0.00876750, max = 0.0141553 (MCP4)
# [info] Frame 854 (t = 29.3673):	 total squared error = 0.00208200, marker error: RMS = 0.00878130, max = 0.0145509 (MCP4)
# [info] Frame 855 (t = 29.4017):	 total squared error = 0.00207098, marker error: RMS = 0.00875803, max = 0.0136943 (MCP4)
# [info] Frame 856 (t = 29.436):	 total squared error = 0.00205858, marker error: RMS = 0.00873176, max = 0.0143431 (MCP4)
# [info] Frame 857 (t = 29.4704):	 total squared error = 0.00226410, marker error: RMS = 0.00915727, max = 0.0144449 (MCP4)
# [info] Frame 858 (t = 29.5048):	 total squared error = 0.00218379, marker error: RMS = 0.00899340, max = 0.0142941 (MCP4)
# [info] Frame 859 (t = 29.5392):	 total squared error = 0.00221779, marker error: RMS = 0.00906314, max = 0.0149202 (MCP4)
# [info] Frame 860 (t = 29.5736):	 total squared error = 0.00220439, marker error: RMS = 0.00903572, max = 0.0141496 (R.clavicle)
# [info] Frame 861 (t = 29.6080):	 total squared error = 0.00214448, marker error: RMS = 0.00891207, max = 0.014755 (R.clavicle)
# [info] Frame 862 (t = 29.6424):	 total squared error = 0.00214713, marker error: RMS = 0.00891759, max = 0.0154408 (MCP2)
# [info] Frame 863 (t = 29.6768):	 total squared error = 0.00204967, marker error: RMS = 0.00871284, max = 0.0157957 (MCP2)
# [info] Frame 864 (t = 29.7111):	 total squared error = 0.00207769, marker error: RMS = 0.00877219, max = 0.0152083 (R.clavicle)
# [info] Frame 865 (t = 29.7455):	 total squared error = 0.00211148, marker error: RMS = 0.00884324, max = 0.0154282 (R.clavicle)
# [info] Frame 866 (t = 29.7799):	 total squared error = 0.00197229, marker error: RMS = 0.00854679, max = 0.0153381 (R.clavicle)
# [info] Frame 867 (t = 29.8143):	 total squared error = 0.00180518, marker error: RMS = 0.00817672, max = 0.0151082 (MCP2)
# [info] Frame 868 (t = 29.8487):	 total squared error = 0.00167213, marker error: RMS = 0.00786960, max = 0.0146994 (MCP2)
# [info] Frame 869 (t = 29.8831):	 total squared error = 0.00152545, marker error: RMS = 0.00751654, max = 0.0143932 (MCP2)
# [info] Frame 870 (t = 29.9175):	 total squared error = 0.00140078, marker error: RMS = 0.00720282, max = 0.0142871 (MCP2)
# [info] Frame 871 (t = 29.9519):	 total squared error = 0.00132281, marker error: RMS = 0.00699951, max = 0.0146994 (MCP2)
# [info] Frame 872 (t = 29.9862):	 total squared error = 0.00123413, marker error: RMS = 0.00676080, max = 0.0142737 (MCP2)
# [info] Frame 873 (t = 30.0206):	 total squared error = 0.00123856, marker error: RMS = 0.00677293, max = 0.0144857 (MCP2)
# [info] Frame 874 (t = 30.055):	 total squared error = 0.00110706, marker error: RMS = 0.00640331, max = 0.0128562 (MCP2)
# [info] Frame 875 (t = 30.0894):	 total squared error = 0.00113431, marker error: RMS = 0.00648164, max = 0.0128699 (MCP2)
# [info] Frame 876 (t = 30.1238):	 total squared error = 0.00104662, marker error: RMS = 0.00622604, max = 0.0122558 (MCP2)
# [info] Frame 877 (t = 30.1582):	 total squared error = 0.000952693, marker error: RMS = 0.00594011, max = 0.0118631 (MCP2)
# [info] Frame 878 (t = 30.1926):	 total squared error = 0.000653104, marker error: RMS = 0.00491823, max = 0.00948852 (MCP2)
# [info] Frame 879 (t = 30.227):	 total squared error = 0.000577968, marker error: RMS = 0.00462669, max = 0.00852987 (MCP2)
# [info] Frame 880 (t = 30.2613):	 total squared error = 0.000382176, marker error: RMS = 0.00376227, max = 0.00782051 (R.clavicle)
# [info] Frame 881 (t = 30.2957):	 total squared error = 0.000282714, marker error: RMS = 0.00323588, max = 0.00839085 (R.clavicle)
# [info] Frame 882 (t = 30.3301):	 total squared error = 0.000239556, marker error: RMS = 0.00297866, max = 0.00833700 (R.clavicle)
# [info] Frame 883 (t = 30.3645):	 total squared error = 0.000231454, marker error: RMS = 0.00292786, max = 0.00814115 (R.clavicle)
# [info] Frame 884 (t = 30.3989):	 total squared error = 0.000246735, marker error: RMS = 0.00302297, max = 0.00788650 (R.clavicle)
# [info] Frame 885 (t = 30.4333):	 total squared error = 0.000237942, marker error: RMS = 0.00296861, max = 0.00784287 (R.clavicle)
# [info] Frame 886 (t = 30.4677):	 total squared error = 0.000228925, marker error: RMS = 0.00291182, max = 0.00715078 (R.clavicle)
# [info] Frame 887 (t = 30.5021):	 total squared error = 0.000258243, marker error: RMS = 0.00309266, max = 0.00694135 (R.Wrist.Medial.pinky)
# [info] Frame 888 (t = 30.5365):	 total squared error = 0.000257010, marker error: RMS = 0.00308527, max = 0.00778667 (R.Wrist.Medial.pinky)
# [info] Frame 889 (t = 30.5708):	 total squared error = 0.000270902, marker error: RMS = 0.00316756, max = 0.00731580 (R.Wrist.Medial.pinky)
# [info] Frame 890 (t = 30.6052):	 total squared error = 0.000296658, marker error: RMS = 0.00331472, max = 0.00768384 (R.Wrist.Medial.pinky)
# [info] Frame 891 (t = 30.6396):	 total squared error = 0.000280696, marker error: RMS = 0.00322431, max = 0.00715396 (R.Wrist.Medial.pinky)
# [info] Frame 892 (t = 30.674):	 total squared error = 0.000270528, marker error: RMS = 0.00316537, max = 0.00660938 (R.Wrist.Medial.pinky)
# [info] Frame 893 (t = 30.7084):	 total squared error = 0.000249513, marker error: RMS = 0.00303994, max = 0.00604097 (R.Wrist.Medial.pinky)
# [info] Frame 894 (t = 30.7428):	 total squared error = 0.000237639, marker error: RMS = 0.00296672, max = 0.00608497 (R.clavicle)
# [info] Frame 895 (t = 30.7772):	 total squared error = 0.000205382, marker error: RMS = 0.00275803, max = 0.00593758 (R.clavicle)
# [info] Frame 896 (t = 30.8116):	 total squared error = 0.000183190, marker error: RMS = 0.00260476, max = 0.00606203 (R.clavicle)
# [info] Frame 897 (t = 30.8459):	 total squared error = 0.000189906, marker error: RMS = 0.00265209, max = 0.00612041 (R.clavicle)
# [info] Frame 898 (t = 30.8803):	 total squared error = 0.000181432, marker error: RMS = 0.00259224, max = 0.00605321 (R.clavicle)
# [info] Frame 899 (t = 30.9147):	 total squared error = 0.000169966, marker error: RMS = 0.00250899, max = 0.00612990 (R.clavicle)
# [info] Frame 900 (t = 30.9491):	 total squared error = 0.000152994, marker error: RMS = 0.00238043, max = 0.00538627 (R.clavicle)
# [info] Frame 901 (t = 30.9835):	 total squared error = 0.000147103, marker error: RMS = 0.00233415, max = 0.00539855 (R.clavicle)
# [info] Frame 902 (t = 31.0179):	 total squared error = 0.000139937, marker error: RMS = 0.00227659, max = 0.00482789 (R.clavicle)
# [info] Frame 903 (t = 31.0523):	 total squared error = 0.000144104, marker error: RMS = 0.00231024, max = 0.00412538 (R.Shoulder.M)
# [info] Frame 904 (t = 31.0867):	 total squared error = 0.000131439, marker error: RMS = 0.00220638, max = 0.00464637 (R.clavicle)
# [info] Frame 905 (t = 31.121):	 total squared error = 0.000138191, marker error: RMS = 0.00226234, max = 0.00498208 (R.clavicle)
# [info] Frame 906 (t = 31.1554):	 total squared error = 0.000132603, marker error: RMS = 0.00221613, max = 0.00471070 (R.clavicle)
# [info] Frame 907 (t = 31.1898):	 total squared error = 0.000128939, marker error: RMS = 0.00218529, max = 0.00466277 (R.clavicle)
# [info] Frame 908 (t = 31.2242):	 total squared error = 0.000130065, marker error: RMS = 0.00219482, max = 0.00479377 (R.clavicle)
# [info] Frame 909 (t = 31.2586):	 total squared error = 0.000136631, marker error: RMS = 0.00224954, max = 0.00473795 (R.clavicle)
# [info] Frame 910 (t = 31.293):	 total squared error = 0.000133811, marker error: RMS = 0.00222620, max = 0.00462834 (R.Wrist.Lateral.Thumb)
# [info] Frame 911 (t = 31.3274):	 total squared error = 0.000126690, marker error: RMS = 0.00216615, max = 0.00418042 (R.Wrist.Lateral.Thumb)
# [info] Frame 912 (t = 31.3618):	 total squared error = 0.000136740, marker error: RMS = 0.00225043, max = 0.00504123 (R.Wrist.Lateral.Thumb)
# [info] Frame 913 (t = 31.3961):	 total squared error = 0.000175938, marker error: RMS = 0.00255269, max = 0.00467769 (MCP2)
# [info] Frame 914 (t = 31.4305):	 total squared error = 0.000206410, marker error: RMS = 0.00276493, max = 0.00568824 (MCP5)
# [info] Frame 915 (t = 31.4649):	 total squared error = 0.000243515, marker error: RMS = 0.00300318, max = 0.00627129 (MCP5)
# [info] Frame 916 (t = 31.4993):	 total squared error = 0.000250380, marker error: RMS = 0.00304522, max = 0.00642047 (MCP5)
# [error] IO.OpenFile(const string&,const string&): failed to open ./Models/Data/Kinematics/m002_trial0_RTMPoseHand5_TopDown_smoothed.mot.
# [error] IO.OpenFile(const string&,const string&): failed to open ./Models/Data/Kinematics/m002_trial0_RTMPoseHand5_TopDown_smoothed_ik_marker_errors.sto.
# [error] IO.OpenFile(const string&,const string&): failed to open ./Models/Data/Kinematics/m002_trial0_RTMPoseHand5_TopDown_smoothed_ik_model_marker_locations.sto.
# [info] InverseKinematicsTool completed 917 frames in 2400 second(s) (40 minute(s), 0 second(s)).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1473526/2659034817.py in ?()
# ----> 1 IK_model( root_dir, trace_file_path, pathScaledModel, IK_file)
#
# /tmp/ipykernel_1473526/1130456458.py in ?(root_dir, trace_file_path, scaled_model_path, IK_file)
#      42                                     trialName)
#      43     os.makedirs(outputJsonVisDir,exist_ok=True)
#      44     outputJsonVisPath = os.path.join(outputJsonVisDir,
#      45                                         trialName + '.json')
# ---> 46     generateVisualizerJson(pathScaledModel, pathOutputIK,
#      47                             outputJsonVisPath,
#      48                             vertical_offset=0)
#      49     return pathOutputIK
#
# ~/projects/opencap-core/utilsOpenSim.py in ?(modelPath, ikPath, jsonOutputPath, statesInDegrees, vertical_offset)
#     638     nCoords = coords.getSize()
#     639     coordNames = [coords.get(i).getName() for i in range(nCoords)]
#     640
#     641     # load IK
# --> 642     stateTable = opensim.TimeSeriesTable(ikPath)
#     643     stateNames = stateTable.getColumnLabels()
#     644     stateTime = stateTable.getIndependentColumn()
#     645     try:
#
# ~/.conda/envs/opencap/lib/python3.9/site-packages/opensim/common.py in ?(self, *args)
#   20602                                        tablename was not specified.
#   20603            :raises: InvalidArgument If the input file contains a table that is not of
#   20604                                        this TimeSeriesTable_ type.
#   20605         """
# > 20606         _common.TimeSeriesTable_swiginit(self, _common.new_TimeSeriesTable(*args))
#
# RuntimeError: std::exception in 'OpenSim::TimeSeriesTable_< double >::TimeSeriesTable_(std::string const &)': File './Models/Data/Kinematics/m002_trial0_RTMPoseHand5_TopDown_smoothed.mot' does not exist.
# 	Thrown at DelimFileAdapter.h:316 in extendRead().

# %%
# %% OpenSim pipeline.
if True:
    openSimPipelineDir = os.path.join('./', "opensimPipeline")        
    
    if True:
        openSimFolderName = 'OpenSimData'
    else:
        openSimFolderName = os.path.join('OpenSimData', 
                                            poseDetector + suff_pd)
        if not markerDataFolderNameSuffix is None:
            openSimFolderName = os.path.join(openSimFolderName,
                                                markerDataFolderNameSuffix)
    
    openSimDir = os.path.join('./', openSimFolderName)        
    outputScaledModelDir = os.path.join(openSimDir, 'Model')

    # # Check if shoulder model.
    # if 'shoulder' in sessionMetadata['openSimModel']:
    #     suffix_model = '_shoulder'
    # else:
    #     suffix_model = ''
    
    # Scaling.    
    if True:
        os.makedirs(outputScaledModelDir, exist_ok=True)
        # Path setup file.
        #CHANGEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
        genericSetupFile4ScalingName = (
            'Setup_scaling_RajagopalModified2016_withArms_KA.xml')
        pathGenericSetupFile4Scaling = os.path.join(
            openSimPipelineDir, 'Scaling', genericSetupFile4ScalingName)
        # Path model file.
        pathGenericModel4Scaling = os.path.join(
            openSimPipelineDir, 'Models', 
            sessionMetadata['openSimModel'] + '.osim')            
        # Path TRC file.
        ##CHANGEEEEEEEEEEEEEEEEEEEEEEEEEEEE
        pathTRCFile4Scaling =  '~/projects/Hand_Detection/trace_files/m002/'
        # Get time range.
        try:
            thresholdPosition = 0.003
            maxThreshold = 0.015
            increment = 0.001
            success = False
            while thresholdPosition <= maxThreshold and not success:
                try:
                    timeRange4Scaling = getScaleTimeRange(
                        pathTRCFile4Scaling,
                        thresholdPosition=thresholdPosition,
                        thresholdTime=0.1, removeRoot=True)
                    success = True
                except Exception as e:
                    print(f"Attempt with thresholdPosition {thresholdPosition} failed: {e}")
                    thresholdPosition += increment  # Increase the threshold for the next iteration

            # Run scale tool.
            print('Running Scaling')
            pathScaledModel = runScaleTool(
                pathGenericSetupFile4Scaling, pathGenericModel4Scaling,
                sessionMetadata['mass_kg'], pathTRCFile4Scaling, 
                timeRange4Scaling, outputScaledModelDir,
                subjectHeight=sessionMetadata['height_m'], 
                suffix_model='')
        except Exception as e:
            if len(e.args) == 2: # specific exception
                raise Exception(e.args[0], e.args[1])
            elif len(e.args) == 1: # generic exception
                exception = "Musculoskeletal model scaling failed. Verify your setup and try again. Visit https://www.opencap.ai/best-pratices to learn more about data collection and https://www.opencap.ai/troubleshooting for potential causes for a failed neutral pose."
                raise Exception(exception, traceback.format_exc())
        # Extract one frame from videos to verify neutral pose.
        staticImagesFolderDir = os.path.join('./', 
                                                'NeutralPoseImages')
        os.makedirs(staticImagesFolderDir, exist_ok=True)
        # popNeutralPoseImages(cameraDirectories, cameras2Use, 
        #                         timeRange4Scaling[0], staticImagesFolderDir,
        #                         trial_id, writeVideo = True)   
        pathOutputIK = pathScaledModel[:-5]+'.mot'     
    
    # Inverse kinematics.
    if True:
        outputIKDir = os.path.join(openSimDir, 'Kinematics')
        os.makedirs(outputIKDir, exist_ok=True)
        # Check if there is a scaled model.
        pathScaledModel = os.path.join(outputScaledModelDir, 
                                        sessionMetadata['openSimModel'] + 
                                        "_scaled.osim")
        if os.path.exists(pathScaledModel):
            # Path setup file.
            genericSetupFile4IKName = 'Setup_IK{}.xml'.format('')
            pathGenericSetupFile4IK = os.path.join(
                openSimPipelineDir, 'IK', genericSetupFile4IKName)
            # Path TRC file.
            #CHANGE
            pathTRCFile4IK = pathAugmentedOutputFiles[trialName]
            # Run IK tool. 
            print('Running Inverse Kinematics')
            try:
                pathOutputIK = runIKTool(
                    pathGenericSetupFile4IK, pathScaledModel, 
                    pathTRCFile4IK, outputIKDir)
            except Exception as e:
                if len(e.args) == 2: # specific exception
                    raise Exception(e.args[0], e.args[1])
                elif len(e.args) == 1: # generic exception
                    exception = "Inverse kinematics failed. Verify your setup and try again. Visit https://www.opencap.ai/best-pratices to learn more about data collection and https://www.opencap.ai/troubleshooting for potential causes for a failed trial."
                    raise Exception(exception, traceback.format_exc())
        else:
            raise ValueError("No scaled model available.")
    
    # Write body transforms to json for visualization.
    outputJsonVisDir = os.path.join(sessionDir,'VisualizerJsons',
                                    trialName)
    os.makedirs(outputJsonVisDir,exist_ok=True)
    outputJsonVisPath = os.path.join(outputJsonVisDir,
                                        trialName + '.json')
    generateVisualizerJson(pathScaledModel, pathOutputIK,
                            outputJsonVisPath, 
                            vertical_offset=vertical_offset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 35
#      30 pathGenericSetupFile4Scaling = os.path.join(
#      31     openSimPipelineDir, 'Scaling', genericSetupFile4ScalingName)
#      32 # Path model file.
#      33 pathGenericModel4Scaling = os.path.join(
#      34     openSimPipelineDir, 'Models',
# ---> 35     sessionMetadata['openSimModel'] + '.osim')
#      36 # Path TRC file.
#      37 ##CHANGEEEEEEEEEEEEEEEEEEEEEEEEEEEE
#      38 pathTRCFile4Scaling = pathAugmentedOutputFiles[trialName]
#
# NameError: name 'sessionMetadata' is not defined
